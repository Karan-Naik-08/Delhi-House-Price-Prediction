# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('MagicBricks.csv')

# %%
df.head(20)
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0    800.0000    3       2.0  Semi-Furnished
# 1    750.0000    2       2.0  Semi-Furnished
# 2    950.0000    2       2.0       Furnished
# 3    600.0000    2       2.0  Semi-Furnished
# 4    650.0000    2       2.0  Semi-Furnished
# 5   1300.0000    4       3.0  Semi-Furnished
# 6   1350.0000    4       3.0  Semi-Furnished
# 7    650.0000    2       2.0  Semi-Furnished
# 8    985.0000    3       3.0     Unfurnished
# 9   1300.0000    4       4.0  Semi-Furnished
# 10  1100.0000    3       2.0  Semi-Furnished
# 11   870.0000    3       2.0  Semi-Furnished
# 12   630.0000    2       2.0  Semi-Furnished
# 13   660.0000    2       2.0  Semi-Furnished
# 14   344.4448    2       2.0  Semi-Furnished
# 15   660.0000    2       2.0  Semi-Furnished
# 16   550.0000    2       2.0  Semi-Furnished
# 17  1100.0000    4       3.0  Semi-Furnished
# 18  1150.0000    3       3.0  Semi-Furnished
# 19   650.0000    2       2.0  Semi-Furnished
#
#                                              Locality  Parking     Price  \
# 0                                    Rohini Sector 25      1.0   6500000
# 1              J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                 Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                    Rohini Sector 24      1.0   4200000
# 4   Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
# 5                                    Rohini Sector 24      1.0  15500000
# 6                                    Rohini Sector 24      1.0  10000000
# 7                       Delhi Homes, Rohini Sector 24      1.0   4000000
# 8                                    Rohini Sector 21      1.0   6800000
# 9                                    Rohini Sector 22      1.0  15000000
# 10                                   Rohini Sector 20      1.0   6200000
# 11                                   Rohini Sector 25      1.0   7700000
# 12                                   Rohini Sector 24      1.0   5500000
# 13                                   Rohini Sector 24      1.0   5000000
# 14  Rohini Sector 8 How Auctions work? The borrowe...      1.0   3310000
# 15  Rohini Sector 25 carpet area 660 sqft status R...      1.0   4700000
# 16                                   Rohini Sector 22      1.0   4500000
# 17                                   Rohini Sector 16      1.0  17000000
# 18                                   Rohini Sector 14      1.0  25000000
# 19                                   Rohini Sector 24      1.0   6000000
#
#            Status   Transaction           Type  Per_Sqft
# 0   Ready_to_move  New_Property  Builder_Floor       NaN
# 1   Ready_to_move  New_Property      Apartment    6667.0
# 2   Ready_to_move        Resale      Apartment    6667.0
# 3   Ready_to_move        Resale  Builder_Floor    6667.0
# 4   Ready_to_move  New_Property  Builder_Floor    6667.0
# 5   Ready_to_move  New_Property  Builder_Floor    6667.0
# 6   Ready_to_move        Resale  Builder_Floor    6667.0
# 7   Ready_to_move  New_Property      Apartment    6154.0
# 8    Almost_ready  New_Property  Builder_Floor    6154.0
# 9   Ready_to_move  New_Property  Builder_Floor    6154.0
# 10  Ready_to_move  New_Property  Builder_Floor    6154.0
# 11  Ready_to_move  New_Property  Builder_Floor    6154.0
# 12  Ready_to_move  New_Property  Builder_Floor    6154.0
# 13  Ready_to_move        Resale  Builder_Floor    6154.0
# 14  Ready_to_move        Resale  Builder_Floor    6154.0
# 15  Ready_to_move  New_Property  Builder_Floor    6154.0
# 16  Ready_to_move  New_Property  Builder_Floor    6154.0
# 17  Ready_to_move  New_Property  Builder_Floor    6154.0
# 18  Ready_to_move        Resale      Apartment    6154.0
# 19  Ready_to_move        Resale  Builder_Floor    6154.0

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
df.nunique()
# Out:
# Area           315
# BHK              8
# Bathroom         7
# Furnishing       3
# Locality       365
# Parking          9
# Price          284
# Status           2
# Transaction      2
# Type             2
# Per_Sqft       251
# dtype: int64

# %%
df.shape
# Out:
# (1259, 11)

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df['Bathroom']=df['Bathroom'].fillna(2)
df['Parking']=df['Parking'].fillna(2)

# %%
df['Furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished', nan], dtype=object)

# %%
sns.countplot(x=df['Furnishing'])
# Out:
# <AxesSubplot:xlabel='Furnishing', ylabel='count'>

# %%
df['Furnishing']=df['Furnishing'].fillna('Semi-Furnished')

# %%
df['Type'].unique()
# Out:
# array(['Builder_Floor', 'Apartment', nan], dtype=object)

# %%
sns.countplot(x=df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
df['Type']=df['Type'].fillna('Apartment')

# %%
sq_mean= df['Per_Sqft'].mean()

# %%
df['Per_Sqft']=df['Per_Sqft'].fillna(sq_mean)

# %%
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Furnishing', 'Locality', 'Parking', 'Price',
#        'Status', 'Transaction', 'Type', 'Per_Sqft'],
#       dtype='object')

# %%
colnm=['BHK', 'Bathroom', 'Furnishing', 'Locality', 'Parking', 'Price',
       'Status', 'Transaction', 'Type', 'Per_Sqft']

# %%
for i in colnm:
  sns.countplot(x=df[i])
  plt.show()

# %%
sns.pairplot(df,hue='Price')

# %%
sns.scatterplot(x=df['Area'],y=df['Price'],hue=df['Price'])
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Price'>

# %%
for i in colnm:
   sns.scatterplot(x=df[i],y=df['Price'],hue=df['Price'])
   plt.show()

# %%
df=df[
      (df.BHK <= 6)
     & (df.Bathroom<=6)
     & (df.Area<=11000)
    
]

# %%
sns.scatterplot(x=df['Area'],y=df['Price'],hue=df['Price'])
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Price'>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['Furnishing']=le.fit_transform(df['Furnishing'])
df['Type']=le.fit_transform(df['Type'])
df['Transaction']=le.fit_transform(df['Transaction'])
df['Status']=le.fit_transform(df['Status'])
df['Locality']=le.fit_transform(df['Locality'])



print(df['Furnishing'].unique())
print (df['Type'].unique())
print( df['Transaction'].unique())
print( df['Status'].unique())
print( df['Locality'].unique())
# Out:
# [1 0 2]
# [1 0]
# [0 1]
# [1 0]
# [283 139  49 281 282  93 278 279 277 286 284 274 273 193 356 275 245 285
#  303 276 169 168 167 357 171 170  89   8  62 328 176  92 342 163  19 336
#  326  48 204  40 216 101 194  52  22 212  18 138 203  21 155 166 105 104
#  103 358  34  37  35  36 304 280 272 343 345 359 108   5 164 119   0 142
#  125 232 341  97 353 348 124 156  29 110 219 177 221 109 147 337 220 146
#  269 144 131 214  23 287 315 360  84 362 288 268 191 190 122 325 143   6
#  364 173 128 172 160 175 174  27 344 102 346 289 158 201 200 347 225 241
#  242 240 261  24  65  68  64  56 305  63  67 349 106 112 351 352  66 159
#   79 350 111  54 314 317 267 152 265 331 114 161 338 319 330 316 299  11
#  264 198 300 247 252 292  16 293 162 296 295 294 297 270 233 262 235 239
#  236 237  76  15 129 199 213 234 165  75 238 327  20 335 266 121  39  26
#  202  25   1 298 263 127 136  91 302 311 230 215 145 222 228 290  51  50
#  248 249   7 323 210 113  13 339 211 126 250 251 226 361 340 308  70  71
#   61  60 329 306 307  69 223 333 332 189 137 334  41  43 140  42  88  14
#  195 197   9 196  33 178 179 180 182 181 355 207  58  55  72 205  74  57
#   81 206  32 209 208 184 324 116 115 157 185  98 130 100  53  99  83  80
#   59  82 354 301 188 246   2 107 318 187 312  10 218 183 243  38 135 118
#    3 120   4 141 363  28  96  30  78 153 244  77 154  85  86 224 321 320
#  322 313 231  12 257 253 260 258 259  87 256 255  31 254 229 123 148  73
#  117 271  94  90 151 149 150 186  95 132 133 309 134 291 192 227 310  44
#   17  46  47 217  45]
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2700150675.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Furnishing']=le.fit_transform(df['Furnishing'])
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2700150675.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type']=le.fit_transform(df['Type'])
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2700150675.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transaction']=le.fit_transform(df['Transaction'])
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2700150675.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Status']=le.fit_transform(df['Status'])
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2700150675.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Locality']=le.fit_transform(df['Locality'])

# %%
df['Bathroom']= df['Bathroom'].astype(int)
df['Parking']= df['Parking'].astype(int)
df['Area']= df['Area'].astype(int)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2601781549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bathroom']= df['Bathroom'].astype(int)
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2601781549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Parking']= df['Parking'].astype(int)
# C:\Users\manas\AppData\Local\Temp\ipykernel_5240\2601781549.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area']= df['Area'].astype(int)

# %%
df['Area']
# Out:
# 0        800
# 1        750
# 2        950
# 3        600
# 4        650
#         ...
# 1253    1200
# 1254    4118
# 1255    1050
# 1256     875
# 1257     990
# Name: Area, Length: 1248, dtype: int32

# %%
x=df.drop([ 'Locality','Price','Per_Sqft' ],axis=1)
y=df['Price']

# %%
print(x)
print(y)
# Out:
#       Area  BHK  Bathroom  Furnishing  Parking  Status  Transaction  Type
# 0      800    3         2           1        1       1            0     1
# 1      750    2         2           1        1       1            0     0
# 2      950    2         2           0        1       1            1     0
# 3      600    2         2           1        1       1            1     1
# 4      650    2         2           1        1       1            0     1
# ...    ...  ...       ...         ...      ...     ...          ...   ...
# 1253  1200    3         3           1        1       1            1     1
# 1254  4118    4         5           2        3       1            0     1
# 1255  1050    3         2           1        3       1            1     1
# 1256   875    3         3           1        3       1            0     1
# 1257   990    2         2           2        1       1            1     1
#
# [1248 rows x 8 columns]
# 0        6500000
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
#           ...
# 1253    16500000
# 1254    55000000
# 1255    12500000
# 1256    17500000
# 1257    11500000
# Name: Price, Length: 1248, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

LR=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=LR.predict(x_test)
error=r2_score(y_test,pred)
error
# Out:
# 0.7308858703963806

# %%
inpt=np.array([['800','3','2','1','2','1','0','1']])

# %%
from num2words import num2words

# %%
def give_pred(inpt):
    inpt=inpt.astype(int)
    predictin=LR.predict(inpt)
    in_words=num2words(predictin,lang='en_IN')
    return in_words

# %%
give_pred(inpt)
# Out:
# c:\Users\manas\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 'eighty-seven lakh, sixteen thousand, eight hundred and seventy-five point four nine eight nine nine four one two five'
